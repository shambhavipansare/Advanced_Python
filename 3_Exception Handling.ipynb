# %%
37/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22056/719420634.py in <module>
# ----> 1 37/0
#
# ZeroDivisionError: division by zero

# %%
for i in 'Hello':
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_22056/497688239.py", line 2
#
#     ^
# IndentationError: expected an indented block

# %%
num = int(input('Number'))
# Out:
# Numberdjwbamwuo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22056/1921468693.py in <module>
# ----> 1 num = int(input('Number'))
#
# ValueError: invalid literal for int() with base 10: 'djwbamwuo'

# %%
num = int(input('Number'))
print(num + 5)
print(num / 2)
print(num * num)
print(num / 2)
print(num * num)
print(num / 2)
print(num * num)
# Out:
# Number10
# 15
# 5.0
# 100
# 5.0
# 100
# 5.0
# 100

# %%
num = int(input('Number'))
print(num + 5)
print(num / 2)
print(num * num)
print(num / 0)
print(num / 2)
print(num * num)
print(num / 2)
print(num * num)
# Out:
# Number20
# 25
# 10.0
# 400
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22056/1535721023.py in <module>
#       3 print(num / 2)
#       4 print(num * num)
# ----> 5 print(num / 0)
#       6 print(num / 2)
#       7 print(num * num)
#
# ZeroDivisionError: division by zero

# %%
try:
    15 / 0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a = int(input('Num a'))
    b = int(input('Num b'))
    result = a / b
    print(result)
except Exception as e:
    print('Error in try blog')
    print(e)
# Out:
# Num a2
# Num b8
# 0.25

# %%
try:
    a = int(input('Num a'))
    b = int(input('Num b'))
    result = a / b
    print(result)
except Exception as e:
    print('Error in try blog')
    print(e)
# Out:
# Num a5
# Num bhii
# Error in try blog
# invalid literal for int() with base 10: 'hii'

# %%
try:
    name = input('Enter your name')
    age = int(input('Age'))
    print(f'Your good name is {name} and your age is {age}')
except :
    print('Error in try blog and may be age is wrong')
# Out:
# Enter your nameshambhavi
# Age20
# Your good name is shambhavi and your age is 20

# %%
try:
    name = input('Enter your name')
    age = int(input('Age'))
    print(f'Your good name is {name} and your age is {age}')
except :
    print('Error in try blog and may be age is wrong')
# Out:
# Enter your nameshambhavi
# Agejdnga
# Error in try blog and may be age is wrong

# %%
def test(a, b):
    try:
        r1 = a + b
        r2 = a / b
        r3 = a * b
        return r1, r2, r3
    except Exception as e:
        return e

# %%
test(1, 2)
# Out:
# (3, 0.5, 2)

# %%
test(5, 0)
# Out:
# ZeroDivisionError('division by zero')

# %%
def test(a, b):
    try:
        r1 = a + b
    except:
        print('Error in r1 a + b')
    try:
        r2 = a / b
    except:
        print('Error in r2 a / b')
    try:
        r3 = a * b
    except:
        print('Error in r3 a * b')
    
    print(r1, r2, r3)

# %%
test(1, 2)
# Out:
# 3 0.5 2

# %%
test(5, 0)
# Out:
# Error in r2 a / b
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22056/543126756.py in <module>
# ----> 1 test(5, 0)
#
# ~\AppData\Local\Temp/ipykernel_22056/1493056228.py in test(a, b)
#      13         print('Error in r3 a * b')
#      14
# ---> 15     print(r1, r2, r3)
#
# UnboundLocalError: local variable 'r2' referenced before assignment

# %% [raw]
# try:
#     # main
# except:
#     # error
# finally:
#     # compulsory executes

# %%
try:
    f = open('test1.txt', 'w')
    f.write('Hello')
except Exception as e:
    print(e)
finally:
    f.close()

# %%
try:
    f = open('test1.txt', 'w')
    f.read()
except Exception as e:
    print(e)
finally:
    f.close()
# Out:
# not readable

# %%
try:
    a = int(input('Num a'))
    b = int(input('Num b'))
    result = a / b
    print(result)
except Exception as e:
    print('Error in try blog')
    print(e)
finally:
    print('Project closed')
# Out:
# Num a6
# Num b3
# 2.0
# Project closed

# %%
try:
    a = int(input('Num a'))
    b = int(input('Num b'))
    result = a / b
    print(result)
except Exception as e:
    print('Error in try blog')
    print(e)
finally:
    print('Project closed')
# Out:
# Num a8
# Num b0
# Error in try blog
# division by zero
# Project closed

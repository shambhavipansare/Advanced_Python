# %%
ls           # directory/location of opened file along with hidden files
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 9E4C-0EDF
#
#  Directory of C:\Users\Dell\DATA SCIENCE\ADVANCED PYTHON
#
# 18-06-2026  01:24 PM    <DIR>          .
# 18-06-2026  01:20 PM    <DIR>          ..
# 18-06-2026  01:24 PM    <DIR>          .ipynb_checkpoints
# 18-06-2026  01:23 PM               588 1_File Handling.ipynb
#                1 File(s)            588 bytes
#                3 Dir(s)   4,317,184,000 bytes free

# %%
f = open('hello.txt', mode = 'r')     # read a file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_63660/2285126947.py in <module>
# ----> 1 f = open('hello.txt', mode = 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello.txt'

# %%
f = open('Hello.txt', mode = 'r+')      # read & write file

# %%
f = open('hello.txt', mode = 'w')       # write a file

# %%
f.write("This is my hello txt file.")
# Out:
# 26

# %%
f.close()    # close the file

# %%
file = open('hello.txt', mode = 'r')

# %%
file.read()
# Out:
# 'This is my hello txt file.'

# %%
file.read()           # cursor is at the end i.e. after fullstop
# Out:
# ''

# %%
file.seek(0)         # shift cursor at the start
# Out:
# 0

# %%
file.read()
# Out:
# 'This is my hello txt file.'

# %%
file.seek(4)
# Out:
# 4

# %%
file.read()
# Out:
# ' is my hello txt file.'

# %%
f.close()

# %%
f = open('test1.txt', mode = 'w')

# %%
f.write('We are learning file handling in python.')
# Out:
# 40

# %%
f.write('Today we will go to movie.')
# Out:
# 26

# %%
f.close()

# %%
f = open('test1.txt', 'r+')

# %%
f.read()
# Out:
# 'We are learning file handling in python.Today we will go to movie.'

# %%
f.write("This is my new sentence.")
# Out:
# 24

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'We are learning file handling in python.Today we will go to movie.This is my new sentence.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('Hello how are you')
# Out:
# 17

# %%
f.read()
# Out:
# 'ile handling in python.Today we will go to movie.This is my new sentence.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()         # over wrote on the previous sentence
# Out:
# 'Hello how are youile handling in python.Today we will go to movie.This is my new sentence.'

# %%
f.close()

# %%
f = open('test2.txt', mode = 'w')

# %%
f.write('This is my first sentence.')
# Out:
# 26

# %%
f.close()

# %%
f = open('test2.txt', mode = 'r+')

# %%
f.read()
# Out:
# 'This is my first sentence.'

# %%
f.write('This is my second sentence.')
# Out:
# 27

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'This is my first sentence.This is my second sentenceThis is my second sentence.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('Note')
# Out:
# 4

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Note is my first sentence.This is my second sentenceThis is my second sentence.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Note is my first sentence.This is my second sentenceThis is my second sentence.'

# %%
f.write('This is my third sentence.')
# Out:
# 26

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Note is my first sentence.This is my second sentenceThis is my second sentence.This is my third sentence.'

# %%
f.write('Hello my name is Shambhavi.')
# Out:
# 27

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Note is my first sentence.This is my second sentenceThis is my second sentence.This is my third sentence.Hello my name is Shambhavi.'

# %%
f.close()

# %%
f = open('multiline.txt', mode = 'w')

# %%
f.write("""We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.

Read more

Today we’re launching Claude Fable 5: a Mythos-class1 model that we’ve made safe for general use.

Fable 5’s capabilities exceed those of any model we’ve ever made generally available. It is state-of-the-art on nearly all tested benchmarks of AI capability, showing exceptional performance in software engineering, knowledge work, vision, scientific research, and many other areas. The longer and more complex the task, the larger Fable 5’s lead over our other models.""")
# Out:
# 649

# %%
f.close()

# %%
f = open('multiline.txt', mode = 'r+')

# %%
f.readline()
# Out:
# 'We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.\n'

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.readline())
# Out:
# We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.\n'

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'Read more\n'

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'Today we’re launching Claude Fable 5: a Mythos-class1 model that we’ve made safe for general use.\n'

# %%
f.readline()
# Out:
# '\n'

# %%
f.readline()
# Out:
# 'Fable 5’s capabilities exceed those of any model we’ve ever made generally available. It is state-of-the-art on nearly all tested benchmarks of AI capability, showing exceptional performance in software engineering, knowledge work, vision, scientific research, and many other areas. The longer and more complex the task, the larger Fable 5’s lead over our other models.'

# %%
f.readline()
# Out:
# ''

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.\n\nRead more\n\nToday we’re launching Claude Fable 5: a Mythos-class1 model that we’ve made safe for general use.\n\nFable 5’s capabilities exceed those of any model we’ve ever made generally available. It is state-of-the-art on nearly all tested benchmarks of AI capability, showing exceptional performance in software engineering, knowledge work, vision, scientific research, and many other areas. The longer and more complex the task, the larger Fable 5’s lead over our other models.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['We are suspending access to Claude Fable 5 and Claude Mythos 5. We apologize for this disruption to our customers and are working to restore access as soon as possible.\n',
#  '\n',
#  'Read more\n',
#  '\n',
#  'Today we’re launching Claude Fable 5: a Mythos-class1 model that we’ve made safe for general use.\n',
#  '\n',
#  'Fable 5’s capabilities exceed those of any model we’ve ever made generally available. It is state-of-the-art on nearly all tested benchmarks of AI capability, showing exceptional performance in software engineering, knowledge work, vision, scientific research, and many other areas. The longer and more complex the task, the larger Fable 5’s lead over our other models.']

# %%
f.close()

# %%
f = open('test3.txt', mode = 'w')

# %%
f.write("""Today we are learning file handling.
We are preparing for full stack data science.
I am expert in machine learning.
AI is amazing.""")
# Out:
# 130

# %%
f.close()

# %%
f = open('test3.txt', mode = 'r+')

# %%
f.read()
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Today we are learning file handling.\n'

# %%
f.readline()
# Out:
# 'We are preparing for full stack data science.\n'

# %%
f.readline()
# Out:
# 'I am expert in machine learning.\n'

# %%
f.readline()
# Out:
# 'AI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['Today we are learning file handling.\n',
#  'We are preparing for full stack data science.\n',
#  'I am expert in machine learning.\n',
#  'AI is amazing.']

# %%
f.seek(0)
# Out:
# 0

# %%
for sentence in f.readlines():
    print(sentence)
# Out:
# Today we are learning file handling.
#
# We are preparing for full stack data science.
#
# I am expert in machine learning.
#
# AI is amazing.

# %%
for sentence in f.readlines():
    print(sentence.split(' '))

# %%
f.seek(0)
# Out:
# 0

# %%
for sentence in f.readlines():
    print(f.readline())

# %%
f.seek(0)
# Out:
# 0

# %%
l = []
for word in f.readline():
    print(l.append(word))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
l
# Out:
# ['T',
#  'o',
#  'd',
#  'a',
#  'y',
#  ' ',
#  'w',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'f',
#  'i',
#  'l',
#  'e',
#  ' ',
#  'h',
#  'a',
#  'n',
#  'd',
#  'l',
#  'i',
#  'n',
#  'g',
#  '.',
#  '\n']

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Today we are learning file handling.\n'

# %%
for i in 'Today we are learning file handling.':
    print(i)
# Out:
# T
# o
# d
# a
# y
#
# w
# e
#
# a
# r
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# f
# i
# l
# e
#
# h
# a
# n
# d
# l
# i
# n
# g
# .

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
f.seek(0)
# Out:
# 0

# %%
text = f.read()

# %%
text
# Out:
# 'Today we are learning file handling.\nWe are preparing for full stack data science.\nI am expert in machine learning.\nAI is amazing.'

# %%
text = text.split('\n')

# %%
text
# Out:
# ['Today we are learning file handling.',
#  'We are preparing for full stack data science.',
#  'I am expert in machine learning.',
#  'AI is amazing.']

# %%
for i in text:
    print(i)
# Out:
# Today we are learning file handling.
# We are preparing for full stack data science.
# I am expert in machine learning.
# AI is amazing.

# %%
for i in text:
    print(i.split('.'))
# Out:
# ['Today we are learning file handling', '']
# ['We are preparing for full stack data science', '']
# ['I am expert in machine learning', '']
# ['AI is amazing', '']

# %%
l2 = []
for i in text:
    print(l2.append(i.replace('.', '')))
# Out:
# None
# None
# None
# None

# %%
'hello.'.replace('.', '')
# Out:
# 'hello'

# %%
l2
# Out:
# ['Today we are learning file handling',
#  'We are preparing for full stack data science',
#  'I am expert in machine learning',
#  'AI is amazing']

# %%
for i in l2:
    print(i.split(' '))
# Out:
# ['Today', 'we', 'are', 'learning', 'file', 'handling']
# ['We', 'are', 'preparing', 'for', 'full', 'stack', 'data', 'science']
# ['I', 'am', 'expert', 'in', 'machine', 'learning']
# ['AI', 'is', 'amazing']

# %%
words = []
for i in l2:
    words.extend(i.split(' '))

# %%
words
# Out:
# ['Today',
#  'we',
#  'are',
#  'learning',
#  'file',
#  'handling',
#  'We',
#  'are',
#  'preparing',
#  'for',
#  'full',
#  'stack',
#  'data',
#  'science',
#  'I',
#  'am',
#  'expert',
#  'in',
#  'machine',
#  'learning',
#  'AI',
#  'is',
#  'amazing']

# %%
words.count('is')
# Out:
# 1

# %%
for i in words:
    print(i, words.count(i))
# Out:
# Today 1
# we 1
# are 2
# learning 2
# file 1
# handling 1
# We 1
# are 2
# preparing 1
# for 1
# full 1
# stack 1
# data 1
# science 1
# I 1
# am 1
# expert 1
# in 1
# machine 1
# learning 2
# AI 1
# is 1
# amazing 1

# %%
text1 = """For most of AI’s history, humans drove every step in its development cycle. But at Anthropic, we are delegating a growing share of AI development to AI systems themselves, which is speeding up our work.

Taken far enough, and given enough compute, that trend points to an AI system capable of fully autonomously designing and developing its own successor. This is called recursive self-improvement. We are not there yet, and recursive self-improvement is not inevitable. But it could come sooner than most institutions are prepared for.

Using public benchmarks and previously unreported data from within Anthropic, The Anthropic Institute is showing that AI is already accelerating the development of AI systems. To take just one example: today, Anthropic engineers on average ship 8x as much code per quarter as they did from 2021-2025.

The technical trends discussed in this piece suggest that AI systems are going to become much more capable in coming years. These trends have huge implications. AI that can build itself would be a major development in the history of technology—one that could bring enormous good for the world in science, healthcare, and beyond. But full recursive self-improvement also might increase the risks of humans losing control over AI systems. If systems are capable of fully building their own successors, the ways we secure them, monitor them, and shape their behavior all grow much more important."""

# %%
f = open('AI.txt', mode = 'w')

# %%
f.write("""For most of AI’s history, humans drove every step in its development cycle. But at Anthropic, we are delegating a growing share of AI development to AI systems themselves, which is speeding up our work.

Taken far enough, and given enough compute, that trend points to an AI system capable of fully autonomously designing and developing its own successor. This is called recursive self-improvement. We are not there yet, and recursive self-improvement is not inevitable. But it could come sooner than most institutions are prepared for.

Using public benchmarks and previously unreported data from within Anthropic, The Anthropic Institute is showing that AI is already accelerating the development of AI systems. To take just one example: today, Anthropic engineers on average ship 8x as much code per quarter as they did from 2021-2025.

The technical trends discussed in this piece suggest that AI systems are going to become much more capable in coming years. These trends have huge implications. AI that can build itself would be a major development in the history of technology—one that could bring enormous good for the world in science, healthcare, and beyond. But full recursive self-improvement also might increase the risks of humans losing control over AI systems. If systems are capable of fully building their own successors, the ways we secure them, monitor them, and shape their behavior all grow much more important.""")
# Out:
# 1433

# %%
f.close()

# %%
text1.split(' ')
# Out:
# ['For',
#  'most',
#  'of',
#  'AI’s',
#  'history,',
#  'humans',
#  'drove',
#  'every',
#  'step',
#  'in',
#  'its',
#  'development',
#  'cycle.',
#  'But',
#  'at',
#  'Anthropic,',
#  'we',
#  'are',
#  'delegating',
#  'a',
#  'growing',
#  'share',
#  'of',
#  'AI',
#  'development',
#  'to',
#  'AI',
#  'systems',
#  'themselves,',
#  'which',
#  'is',
#  'speeding',
#  'up',
#  'our',
#  'work.\n\nTaken',
#  'far',
#  'enough,',
#  'and',
#  'given',
#  'enough',
#  'compute,',
#  'that',
#  'trend',
#  'points',
#  'to',
#  'an',
#  'AI',
#  'system',
#  'capable',
#  'of',
#  'fully',
#  'autonomously',
#  'designing',
#  'and',
#  'developing',
#  'its',
#  'own',
#  'successor.',
#  'This',
#  'is',
#  'called',
#  'recursive',
#  'self-improvement.',
#  'We',
#  'are',
#  'not',
#  'there',
#  'yet,',
#  'and',
#  'recursive',
#  'self-improvement',
#  'is',
#  'not',
#  'inevitable.',
#  'But',
#  'it',
#  'could',
#  'come',
#  'sooner',
#  'than',
#  'most',
# ...

# %%
[i for i in text1]
# Out:
# ['F',
#  'o',
#  'r',
#  ' ',
#  'm',
#  'o',
#  's',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'A',
#  'I',
#  '’',
#  's',
#  ' ',
#  'h',
#  'i',
#  's',
#  't',
#  'o',
#  'r',
#  'y',
#  ',',
#  ' ',
#  'h',
#  'u',
#  'm',
#  'a',
#  'n',
#  's',
#  ' ',
#  'd',
#  'r',
#  'o',
#  'v',
#  'e',
#  ' ',
#  'e',
#  'v',
#  'e',
#  'r',
#  'y',
#  ' ',
#  's',
#  't',
#  'e',
#  'p',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  'i',
#  't',
#  's',
#  ' ',
#  'd',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
#  'm',
#  'e',
#  'n',
#  't',
#  ' ',
#  'c',
#  'y',
#  'c',
#  'l',
#  'e',
#  '.',
#  ' ',
#  'B',
#  'u',
#  't',
#  ' ',
#  'a',
#  't',
#  ' ',
#  'A',
#  'n',
#  't',
#  'h',
#  'r',
#  'o',
#  'p',
#  'i',
#  'c',
#  ',',
#  ' ',
#  'w',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  'd',
#  'e',
#  'l',
#  'e',
#  'g',
#  'a',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'a',
#  ' ',
#  'g',
#  'r',
#  'o',
#  'w',
#  'i',
#  'n',
#  'g',
#  ' ',
#  's',
#  'h',
#  'a',
# ...

# %%
text1.split('\n')
# Out:
# ['For most of AI’s history, humans drove every step in its development cycle. But at Anthropic, we are delegating a growing share of AI development to AI systems themselves, which is speeding up our work.',
#  '',
#  'Taken far enough, and given enough compute, that trend points to an AI system capable of fully autonomously designing and developing its own successor. This is called recursive self-improvement. We are not there yet, and recursive self-improvement is not inevitable. But it could come sooner than most institutions are prepared for.',
#  '',
#  'Using public benchmarks and previously unreported data from within Anthropic, The Anthropic Institute is showing that AI is already accelerating the development of AI systems. To take just one example: today, Anthropic engineers on average ship 8x as much code per quarter as they did from 2021-2025.',
#  '',
# ...

# %%
'hello.'.replace('.', '')
# Out:
# 'hello'

# %%
'10-12-2017'
# Out:
# '10-12-2017'

# %%
'10-12-2017'.split('-')[1]
# Out:
# '12'

# %%
int('10-12-2017'.split('-')[1])
# Out:
# 12

# %%
def month(n):
    result = n.split('-')[1]
    result = int(result)
    return result

# %%
month('10-12-2017')
# Out:
# 12

# %%
type(month('10-12-2017'))
# Out:
# int

# %%
p = open('functions.py', mode = 'w')

# %%
p.write("""# This is functions
def square(n):
    return n*n
    
def add(a, b):
    return a+b
""")
# Out:
# 85

# %%
p.close()

# %%
p = open('all functions.py', mode = 'w')

# %%
p.write("""
def test6(*args):
    return args
    
def int_filter(*args):
    l = []
    for i in args:
        if type(i) == int:
            l.append(i)
    return l
    
def even_odd(n):
    if n % 2 == 0:
        return 'Even', n
    else:
        return 'Odd', n
        
""")
# Out:
# 266

# %%
p.close()

# %%
def square(n):
    return n * n

# %%
square(4)
# Out:
# 16
